# %%
import os 
import mne 
import numpy as np

# %%
dir_path = './dane_cyfry'

file_paths = []

for root, dirs, files in os.walk(dir_path):
    for file in files:
        file_path = os.path.join(root, file)
        file_paths.append(file_path)

print(file_paths)
# Out:
# ['./dane_cyfry/cyfry/GS004.fif', './dane_cyfry/cyfry/GS005.fif', './dane_cyfry/cyfry/GS006.fif', './dane_cyfry/cyfry/GS003.fif', './dane_cyfry/cyfry/GS002.fif', './dane_cyfry/cyfry/DJ002.fif', './dane_cyfry/cyfry/DJ001.fif', './dane_cyfry/cyfry/GS001.fif', './dane_cyfry/cyfry/loading_the_data.ipynb']

# %%
data_raw_file = file_paths[6]
raw = mne.io.read_raw_fif(data_raw_file, preload=True)
raw.load_data()
# Out:
# <Raw | DJ001.fif, 21 x 196525 (786.1 s), ~31.5 MB, data loaded>

# %%
# mag_channels = mne.pick_types(raw.info, meg='mag')
# raw.plot_psd(picks=mag_channels, fmax=50)

# %%
raw.plot_psd(fmax=50)
# Out:
# /home/grzesiek/miniconda3/envs/mne/lib/python3.12/site-packages/mne/viz/utils.py:167: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   (fig or plt).show(**kwargs)
# <MNELineFigure size 1000x350 with 2 Axes>
# <MNELineFigure size 1000x350 with 2 Axes>

# %%
print(raw.info['ch_names'])
print(raw.get_channel_types())
# Out:
# ['Fp1', 'Fp2', 'F3', 'F4', 'C3', 'C4', 'P3', 'P4', 'O1', 'O2', 'T3', 'T4', 'T5', 'T6', 'F7', 'F8', 'Accel_x', 'Accel_y', 'Accel_z', 'Digital', 'Sample']
# ['eeg', 'eeg', 'eeg', 'eeg', 'eeg', 'eeg', 'eeg', 'eeg', 'eeg', 'eeg', 'eeg', 'eeg', 'eeg', 'eeg', 'eeg', 'eeg', 'misc', 'misc', 'misc', 'stim', 'syst']

# %%
# import plotly.express as px

# fig = px.line(x=raw.times, y=raw.get_data()[0], title='EEG Signal')
# fig.show()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 import plotly.express as px
#       3 fig = px.line(x=raw.times, y=raw.get_data()[0], title='EEG Signal')
#       4 fig.show()
#
# ModuleNotFoundError: No module named 'plotly'

# %%
# ecg_epochs = mne.preprocessing.create_ecg_epochs(raw)
# ecg_epochs.plot_image(combine='mean')
